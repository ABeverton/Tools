# %%
import zipfile
import shutil
import os

# Specify your CSV file path (assume it's stored in DBFS)
csv_file_path = '/Workspace/Users/andy.beverton@environment-agency.gov.uk/Denver Complex/Flow obs data/Grace Flows/Set date range/Projected/Reduced arrays/Combined/Med_all_projected_inflows_NO_ELY_OUSE_1976_2022.csv'  # Replace with your actual path
zipped_file_path = '/Workspace/Users/andy.beverton@environment-agency.gov.uk/Denver Complex/Flow obs data/Grace Flows/Set date range/Projected/Reduced arrays/Combined/Med_all_projected_inflows_NO_ELY_OUSE_1976_2022.csv.zip'  # Destination path for the zipped file

# Step 1: Zip the CSV file
with zipfile.ZipFile(zipped_file_path, 'w', zipfile.ZIP_DEFLATED) as zipf:
    zipf.write(csv_file_path, os.path.basename(csv_file_path))  # Add the CSV file to the zip archive

print(f"CSV file has been zipped successfully: {zipped_file_path}")

# Step 2: Generate a link for downloading the file (only accessible within Databricks)
download_link = f'/Workspace/Users/andy.beverton@environment-agency.gov.uk/Denver Complex/Flow obs data/Grace Flows/Set date range/Projected/Reduced arrays/Combined/Med_all_projected_inflows_NO_ELY_OUSE_1976_2022.csv.zip'  # This is for downloading within Databricks UI
print(f"Download your zipped file from: {download_link}")
